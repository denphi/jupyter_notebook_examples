# %% [markdown]
# <div class="well well-lg"><h1>Notebook Users Guide</h1></div>

# %% [markdown]
# * [What is the Notebook?](intro.ipynb#What-is-the-Notebook?)
#   * [Components](intro.ipynb#Components)
#   * [Notebook Web Application](intro.ipynb#Notebook-Web-Application)
#   * [Kernels](intro.ipynb#Kernels)
#   * [Notebook Documents](intro.ipynb#Notebook-Documents)
# * [Notebook Basics](basics.ipynb)
#   * [The Notebook Dashboard](basics.ipynb#The-Notebook-Dashboard)
#   * [Overview of the Notebook UI](basics.ipynb#Overview-of-the-Notebook-UI)
# * [Markdown Cells](markdown.ipynb)
# * [Images in Markdown Cells](images.ipynb)
# * Code Cells
#   * [Running Code](Running%20Code.ipynb)
#   * [Python Cells](python.ipynb)
#   * Plotting
#   * Animations and Movies
# * [Language Support](#Language-Support)
# * [Licenses]

# %% [markdown]
# # The Dashboard (Tree View of Files)

# %% [markdown]
# When you first start the notebook server, your browser will open to the notebook dashboard. The dashboard serves as a home page for the notebook. Its main purpose is to display the notebooks and files in the current directory. For example, here is a screenshot of the dashboard page for the `examples` directory in the Jupyter repository:
#
# <img src="images/dashboard_files_tab.png" width="791px"/>

# %% [markdown]
#     * Requirements: html5 and webgl
# * Toolbar
# * Cells
# 	* Code Cells
#         * running
#         * editing
#         * multimedia output
#             * images
#             * javascript
#             * html/css
#             * sound
#         * plotting
#         * magic
# 	* Markdown
#         * Headers
# 		* Automatic Section Numbering and Table of Contents Support
#         * Bibliographic Support
#         * MD syntax
#         * HTML
#         * Embedding images
#             * drag and drop
#         * Animations and Videos
#      * Raw
# * Kernels
#     * Python2 and 3
#     * Matlab and Octave
#         * oct2py
#     * R
#         * r2py
# * Managing Running Notebooks
# * Terminal
# * Slideshows
# * Exporting Notebooks
# * Printing
# *
# * nanoHUB Installation Details
#     * Extensions
#     * Notebook Settings
#     * The notebooks directory
#     * Installed Modules
#
# * Licenses

# %% [markdown]
# ## Installed Modules
#
# This notebook is running in a linux environment with a large collection of hundreds of scientific packages based on Continuum Analytics Anaconda distribution.  You can get a list of installed packages from within a notebook by executing the cell below.

# %% [markdown]
# If we just do
#
#     !conda list
#
# the notebook server will run the command and return the result,  Unfortunately that will just give us the packages installed in the server's environment.  We really want the results for the packages in the kernel we are using.  To get that we have to do something like:

# %%
# !pwd
# Out:
# /opt/demo

# %%
# Use internal APIs to get list of packages in this environment
# WARNING: using undocumented API calls
from conda.cli.main_list import print_packages
from conda.config import root_dir
print_packages(root_dir, piplist=True)
# Out:
# # packages in environment at /opt/anaconda3-4.1.1:
# #
# alabaster                 0.7.8                    py35_0
# anaconda-client           1.5.1                    py35_0
# anaconda                  custom                   py35_0
# anaconda-navigator        1.2.3                    py35_0
# argcomplete               1.0.0                    py35_1
# ase                       3.11.0                    <pip>
# astropy                   1.2.1               np111py35_0
# atomman                   0.6                       <pip>
# babel                     2.3.3                    py35_0
# backports                 1.0                      py35_0
# basemap                   1.0.7               np111py35_0
# beautifulsoup4            4.5.1                    py35_0
# biopython                 1.67                np111py35_0
# bitarray                  0.8.1                    py35_0
# blaze                     0.10.1                   py35_0
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.5.2 |Anaconda custom (64-bit)| (default, Jul  2 2016, 17:53:06)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %% [markdown]
# ## Language Support
# At the moment only Python 2 and Python 3 are installed. You can select the language when you create a new notebook, or at any time by selecting "Kernel/Change kernel" from the menubar.
# In the future, we will likely add other languages.
