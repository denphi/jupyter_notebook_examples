% %% [markdown]
% # Status
%
% Currently, only Matlab 2021 is available for a notebook, although it is possible to have different versions of Matlab installed.

% %%
t = 2*pi*linspace(0,1,1024)
% Out:
% t =
%
%   Columns 1 through 7
%
%          0    0.0061    0.0123    0.0184    0.0246    0.0307    0.0369
%
%   Columns 8 through 14
%
%     0.0430    0.0491    0.0553    0.0614    0.0676    0.0737    0.0798
%
%   Columns 15 through 21
%
%     0.0860    0.0921    0.0983    0.1044    0.1106    0.1167    0.1228
%
%   Columns 22 through 28
%
%     0.1290    0.1351    0.1413    0.1474    0.1535    0.1597    0.1658
%
%   Columns 29 through 35
%
%     0.1720    0.1781    0.1843    0.1904    0.1965    0.2027    0.2088
%
%   Columns 36 through 42
%
%     0.2150    0.2211    0.2273    0.2334    0.2395    0.2457    0.2518
%
%   Columns 43 through 49
%
%     0.2580    0.2641    0.2702    0.2764    0.2825    0.2887    0.2948
%
%   Columns 50 through 56
%
%     0.3010    0.3071    0.3132    0.3194    0.3255    0.3317    0.3378
%
%   Columns 57 through 63
%
%     0.3439    0.3501    0.3562    0.3624    0.3685    0.3747    0.3808
%
%   Columns 64 through 70
%
% ...

% %%
y = sin(3.14*t) + 0.5*cos(6.09*t) + 0.1*sin(10.11*t+1/6) + 0.1*sin(15.3*t+1/3);

% %%
data1 = abs(y)';

% %%
[pks idx] = findpeaks(data1);
data2 = y;

% %%
subplot(1,2,1)
plot(t,data1,t(idx),data1(idx),'.m')
legend("Location","NorthOutside","Orientation","horizontal")
