# %% [markdown]
# # Plotting
#
# ## Matplotlib
#
# By default matplotlib plots are static inline images.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 50
xp = np.random.rand(N)
yp = np.random.rand(N)
colors = np.random.rand(N)
radii = 15 * np.random.rand(N)
area = np.pi * radii**2  # 0 to 15 point radiuses

plt.scatter(xp, yp, s=area, c=colors, alpha=0.5)
plt.show()

# %%
x = np.linspace(0, 10)
line, = plt.plot(x, np.sin(x), linewidth=2)
plt.show()

# %% [markdown]
# You can switch to a more interactive output for the notebook by using

# %%
# %matplotlib notebook

# %%
plt.scatter(xp, yp, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Seaborn
#
# seaborn is a library built on top of matplotlib.  It has excellent statistical plots. It also has a different style, which you can easily use for more basic plots.

# %%
import seaborn as sns
sns.set_style("darkgrid")

plt.figure()
line, = plt.plot(x, np.sin(x), linewidth=2)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.scatter(xp, yp, s=area, c=colors, alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# bokeh

# %%
from bokeh.plotting import figure, show, output_file, vplot
from bokeh.io import output_notebook

# %%
# this needs to be alone in the cell
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9e85ddc7-540a-4262-a20f-a51dae251365">Loading BokehJS ...</span>
#     </div>

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select"

p = figure(title="Basic Line Example", tools=TOOLS)
p.line(x, np.sin(x), legend="sin(x)")

show(p);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4f51aa3d-3a3f-4a58-944a-93bfb2df1331"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4f51aa3d-3a3f-4a58-944a-93bfb2df1331");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4f51aa3d-3a3f-4a58-944a-93bfb2df1331' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"26b86219-76b3-4143-92d3-ee3dfc0c7e85":{"roots":{"references":[{"attributes":{"formatter":{"id":"fd92aff5-8419-4e1d-b01a-7f8ec06c6200","type":"BasicTickFormatter"},"plot":{"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e48231e-0669-42da-979a-365cc6b2491c","type":"BasicTicker"}},"id":"487b0ab4-5dd7-4bac-97cb-4095ef20a72d","type":"LinearAxis"},{"attributes":{"below":[{"id":"53655951-48c7-4f54-9554-f19990507642","type":"LinearAxis"}],"left":[{"id":"487b0ab4-5dd7-4bac-97cb-4095ef20a72d","type":"LinearAxis"}],"renderers":[{"id":"53655951-48c7-4f54-9554-f19990507642","type":"LinearAxis"},{"id":"417a51fc-9587-465c-b86b-9307b3cebcc7","type":"Grid"},{"id":"487b0ab4-5dd7-4bac-97cb-4095ef20a72d","type":"LinearAxis"},{"id":"d5a2875b-ecac-47ee-a943-9463bbb3c471","type":"Grid"},{"id":"a662fec0-748f-4468-83c8-8fdee00e93d8","type":"BoxAnnotation"},{"id":"bd1e6a61-8b50-4093-a40b-b55332eb3a2e","type":"BoxAnnotation"},{"id":"4000a995-3ca7-4a9f-b3c8-aacc1a40751f","type":"Legend"},{"id":"c8b34657-f1f1-4f06-9897-b85793afd0c1","type":"GlyphRenderer"}],"title":{"id":"e3d7f463-3648-42e3-bd59-4a77ee52b473","type":"Title"},"tool_events":{"id":"aba1e70c-6fc9-4ce1-a13d-becbedc643a4","type":"ToolEvents"},"toolbar":{"id":"40be43ea-3226-4a9d-8287-bd524e9e4f19","type":"Toolbar"},"x_range":{"id":"19039593-661e-45d8-b62d-cfd638ae4b21","type":"DataRange1d"},"y_range":{"id":"646aef48-0aff-44da-858b-a6ef6d6a6f8f","type":"DataRange1d"}},"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"}},"id":"5b5bdac5-3898-4a08-afde-003c84141443","type":"ResetTool"},{"attributes":{"formatter":{"id":"721d87d2-70f8-4bbf-b4f7-19c83d205155","type":"BasicTickFormatter"},"plot":{"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"},"ticker":{"id":"f53a997e-e56b-445c-be4e-276bebb32f49","type":"BasicTicker"}},"id":"53655951-48c7-4f54-9554-f19990507642","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a662fec0-748f-4468-83c8-8fdee00e93d8","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e48231e-0669-42da-979a-365cc6b2491c","type":"BasicTicker"}},"id":"d5a2875b-ecac-47ee-a943-9463bbb3c471","type":"Grid"},{"attributes":{},"id":"6e48231e-0669-42da-979a-365cc6b2491c","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Basic Line Example"},"id":"e3d7f463-3648-42e3-bd59-4a77ee52b473","type":"Title"},{"attributes":{"callback":null},"id":"646aef48-0aff-44da-858b-a6ef6d6a6f8f","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"bd1e6a61-8b50-4093-a40b-b55332eb3a2e","type":"BoxAnnotation"},"plot":{"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"},"renderers":[{"id":"c8b34657-f1f1-4f06-9897-b85793afd0c1","type":"GlyphRenderer"}]},"id":"501dad70-5315-48c1-af05-06a89eacd08a","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"41c7fb69-5338-416a-84dc-310948f74d26","subtype":"Figure","type":"Plot"}},"id":"7f7edc1a-aef0-4e83-85b5-3f21e7932e1f","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9480db67-2b8d-4bc6-9389-b76d6b3eb403","type":"Line"},{"attributes":{"callback":null},"id":"19039593-661e-45d8-b62d-cfd638ae4b21","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"08a1ce7b-76bc-40dd-aee3-33a953948b55","type":"Line"},{"attributes":{},"id":"fd92aff5-8419-4e1d-b01a-7f8ec06c6200","type" ...

# %%
# we will color this by radius
import matplotlib as mpl
bcolors = [
    "#%02x%02x%02x" % (int(r), int(g), int(b)) for r, g, b, _ in 255*mpl.cm.jet(mpl.colors.Normalize()(radii))
]
p = figure(title="Basic Scatter Plot", tools=TOOLS)
p.circle(xp, yp, radius=radii/500, fill_color=bcolors, fill_alpha=0.5, line_color=None)
show(p);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bb7cf0b5-4e6e-419c-a8c3-3ba430bf059f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bb7cf0b5-4e6e-419c-a8c3-3ba430bf059f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bb7cf0b5-4e6e-419c-a8c3-3ba430bf059f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e9abf893-ee24-4631-b17c-b3c26640eb64":{"roots":{"references":[{"attributes":{"plot":null,"text":"Basic Scatter Plot"},"id":"fccfe97b-f086-4c41-a75f-9a18ebd97b17","type":"Title"},{"attributes":{},"id":"680c1386-5653-4b80-8413-312ee03f3e83","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba30bb6b-06de-4ab6-8baf-e69b4f2a72ff","type":"Circle"},{"attributes":{"overlay":{"id":"a6953f59-7f7a-4364-b66e-388809a1e85c","type":"BoxAnnotation"},"plot":{"id":"ad36cc63-6198-4bb0-8c28-41589b58ff58","subtype":"Figure","type":"Plot"}},"id":"bcf0e8ba-9913-45d4-919c-0f416a3fb9b3","type":"BoxZoomTool"},{"attributes":{},"id":"9ae03b5d-8c85-442d-8d6f-e408dcd68ba7","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":