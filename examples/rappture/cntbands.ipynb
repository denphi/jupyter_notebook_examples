# %% [markdown]
# # CNTBANDS

# %%
import hublib.rappture as rappture

# %%
io = rappture.Tool('cntbands-ext')
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.structure()</td><td></td><td></td></tr><tr bgcolor="#dddddd"><td>input.group(chirality).integer(CarbonTypeN)</td><td>n</td><td>
# In Carbon Nanotubes (CNT):
# The chiralit</td></tr><tr bgcolor="#ffffff"><td>input.group(chirality).integer(CarbonTypeM)</td><td>m</td><td>
# In Carbon Nanotubes (CNT):
# The chiralit</td></tr><tr bgcolor="#dddddd"><td>input.group(model).number(TightBindingEnergy)</td><td>Tight Binding Energy</td><td>This is the tight binding overlap integr</td></tr><tr bgcolor="#ffffff"><td>input.group(model).number(CenterToCenter)</td><td>Carbon-carbon spacing</td><td>This is the distance between the centers</td></tr><tr bgcolor="#dddddd"><td>input.integer(NumCellForTube)</td><td>Length in 3-D view</td><td>This determines the length of the nanost</td></tr></table>
# <h3>Loaders</h3><table><tr bgcolor="#dddddd"><td>/apps/cntbands-ext/current/rappture/examples/CNT.xml</td></tr><tr bgcolor="#ffffff"><td>/apps/cntbands-ext/current/rappture/examples/GNR.xml</td></tr></table>

# %%
io.load("/apps/cntbands-ext/current/rappture/examples/GNR.xml")

# %%
io.run()

# %% [markdown]
# ## Get List of Inputs and Outputs

# %%
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.structure()</td><td></td><td></td></tr><tr bgcolor="#dddddd"><td>input.group(chirality).integer(CarbonTypeN)</td><td>n</td><td>
# In Carbon Nanotubes (CNT):
# The chiralit</td></tr><tr bgcolor="#ffffff"><td>input.group(chirality).integer(CarbonTypeM)</td><td>m</td><td>
# In Carbon Nanotubes (CNT):
# The chiralit</td></tr><tr bgcolor="#dddddd"><td>input.group(model).number(TightBindingEnergy)</td><td>Tight Binding Energy</td><td>This is the tight binding overlap integr</td></tr><tr bgcolor="#ffffff"><td>input.group(model).number(CenterToCenter)</td><td>Carbon-carbon spacing</td><td>This is the distance between the centers</td></tr><tr bgcolor="#dddddd"><td>input.integer(NumCellForTube)</td><td>Length in 3-D view</td><td>This determines the length of the nanost</td></tr></table>
# <h3>Loaders</h3><table><tr bgcolor="#dddddd"><td>/apps/cntbands-ext/current/rappture/examples/CNT.xml</td></tr><tr bgcolor="#ffffff"><td>/apps/cntbands-ext/current/rappture/examples/GNR.xml</td></tr></table><h3>OUTPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>output.log()</td><td></td><td></td></tr><tr bgcolor="#dddddd"><td>output.structure(ribbon)</td><td>Molecular structure: overall</td><td></td></tr><tr bgcolor="#ffffff"><td>output.structure(cell)</td><td>Molecular structure: unit cell</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E2)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E3)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E4)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E5)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E6)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E7)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E8)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E9)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E10)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E11)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E12)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E13)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(E14)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#ffffff"><td>output.curve(E15)</td><td>Energy vs. Axial Wave Vector</td><td></td></tr><tr bgcolor="#dddddd"><td>output.curve(DOS)</td><td>Density-Of-States vs. Energy</td><td></td></tr></table>
# <h3>CURVE GROUPS</h3>
# <table><tr bgcolor="#cccccc"><th>Density-Of-States vs. Energy</th>
# <tr bgcolor="#ffffff"><td>output.curve(DOS)</td></tr>
# </table><table><tr bgcolor="#cccccc"><th>Energy vs. Axial Wave Vector</th>
# <tr bgcolor="#ffffff"><td>output.curve(E2)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E3)</td></tr>
# <tr bgcolor="#ffffff"><td>output.curve(E4)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E5)</td></tr>
# <tr bgcolor="#ffffff"><td>output.curve(E6)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E7)</td></tr>
# <tr bgcolor="#ffffff"><td>output.curve(E8)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E9)</td></tr>
# <tr bgcolor="#ffffff"><td>output.curve(E10)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E11)</td></tr>
# <tr bgcolor="#ffffff"><td>output.curve(E12)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E13)</td></tr>
# <tr bgcolor="#ffffff"><td>output.curve(E14)</td></tr>
# <tr bgcolor="#dddddd"><td>output.curve(E15)</td></tr>
# </table>

# %%
# %matplotlib notebook
x = io['output.curve(DOS)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.curve(E2)'].plot(single=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.curve(E2)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.structure(ribbon)'].plot()

# %%
io['output.structure(cell)'].plot()

# %%
print io['output.log'].value
# Out:
# ************************
#  Basic Input Parameters
# ************************
#
# Cut-off vector parameters (n,m)
#  7
#  7
#
# Carbon center to center distance (Ang)
#  1.4200
#
# Tight binding overlap integral (eV)
#  3
#
# Carbon nanoribbon type
# B
# N
#
#
# ***************************
# Output of Basic Parameters:
# ***************************
#
# Length of unit cell (nm)
#  0.24595
# Boundary of Brillouin Zone (ktmax)
#  1.2773e+10
# Bandgap Magnitude (eV)
#  0.0051229
# Bandgap Magnitude in units of overlap parameter (t)
#  0.0017076
