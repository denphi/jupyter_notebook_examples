# %%
# %matplotlib notebook
import numpy as np
import hublib.rappture as rappture

# %%
io = rappture.Tool("rtdnegf")
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.phase(phs2).choice(band_model)</td><td>Energy Band model</td><td></td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).integer(dummy)</td><td>dummy</td><td></td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).number(temperature)</td><td>Ambient temperature</td><td>This is the temperature in the environme</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(basic).number(bias_min)</td><td>Starting Bias</td><td>This is the minimum voltage applied to t</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).number(bias_max)</td><td>Ending Bias</td><td>This is the maximum voltage applied to t</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(basic).integer(bias_step)</td><td>No. of points</td><td>This is the number of voltage points.</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).choice(selfc)</td><td>Potential Model</td><td>Describes the electrostatic potential la</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(basic).choice(quantumc)</td><td>Quantum charge</td><td>The 'Thomas-Fermi' Potential model has n</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).number(latticeconstant)</td><td>Lattice Constant</td><td></td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(domains).number(semiclassical)</td><td>Semiclassical Charge Region (dSC)</td><td>Specify boundary of the region over whic</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(domains).number(equilibrium)</td><td>Equilibrium Region (dEQ)</td><td>Specify the boundary of the region which</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(domains).image()</td><td></td><td></td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).choice(notnormalizedcurrentplot)</td><td>Not-Normalized Current Plot</td><td>If this option is set to ON, the user ge</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(advanced).choice(scatterplot)</td><td>Resonances Scatter Plots</td><td>If this option is set to ON then the sca</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).choice(ldosplot)</td><td>Carrier Distribution Surface Plots</td><td>Turning this option on will display the </td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(advanced).choice(etamodel)</td><td>Reservoir Relaxation Model</td><td>The central device barriers are isolatin</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).number(eta)</td><td>Reservoir Relaxation Energy</td><td>Rate of relaxation in the contacts.  Typ</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(advanced).number(eta2)</td><td>Decay Length.</td><td>Decay length of the Reservoir relaxation</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).number(poisson)</td><td>Poisson Criterion</td><td>The maximum value in the electrostatic p</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(adaptive).choice(Eadaptive)</td><td>Adaptive energy grid</td><td>If set to off, a uniform energy grid wil</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(adaptive).number(Edif)</td><td>Homogeneous E grid spacing</td><td>Energy spacing for the homogeneous energ</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(adaptive).number(Ethreshold)</td><td>Threshold for adding E points</td><td>When the potential change from one itera</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(adaptive).number(Eaddcriterion)</td><td>Criterion for adding E points</td><td>Criterion for determining when E points </td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(adaptive).number(band_margin)</td><td>| Emax-Ef | for each bias</td><td>Quantities such as transmission, current</td></t ...
# <h3>LOADERS</h3>
# <table><tr bgcolor="#cccccc"><th>input.phase(phs2).loader</th><th>Label</th>
# <tr bgcolor="#dddddd"><td>/apps/rtdnegf/current/rappture/examples/3bar.xml</td><td>3-barrier device</td></tr><tr bgcolor="#ffffff"><td>/apps/rtdnegf/current/rappture/examples/6bar.xml</td><td>6-barrier device</td></tr><tr bgcolor="#dddddd"><td>/apps/rtdnegf/current/rappture/examples/1bar.xml</td><td>1-barrier device</td></tr><tr bgcolor="#ffffff"><td>/apps/rtdnegf/current/rappture/examples/2bar.xml</td><td>2-barrier device</td></tr></table>

# %%
#io['input.phase(phs2).loader'] = "/apps/rtdnegf/current/rappture/examples/3bar.xml"

# %%
io['input.phase(phs2).loader'].value
# Out:
# '2-barrier device'

# %%
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>input.phase(phs2).choice(band_model)</td><td>Energy Band model</td><td></td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).integer(dummy)</td><td>dummy</td><td></td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).number(temperature)</td><td>Ambient temperature</td><td>This is the temperature in the environme</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(basic).number(bias_min)</td><td>Starting Bias</td><td>This is the minimum voltage applied to t</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).number(bias_max)</td><td>Ending Bias</td><td>This is the maximum voltage applied to t</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(basic).integer(bias_step)</td><td>No. of points</td><td>This is the number of voltage points.</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).choice(selfc)</td><td>Potential Model</td><td>Describes the electrostatic potential la</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(basic).choice(quantumc)</td><td>Quantum charge</td><td>The 'Thomas-Fermi' Potential model has n</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(basic).number(latticeconstant)</td><td>Lattice Constant</td><td></td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(domains).number(semiclassical)</td><td>Semiclassical Charge Region (dSC)</td><td>Specify boundary of the region over whic</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(domains).number(equilibrium)</td><td>Equilibrium Region (dEQ)</td><td>Specify the boundary of the region which</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(domains).image()</td><td></td><td></td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).choice(notnormalizedcurrentplot)</td><td>Not-Normalized Current Plot</td><td>If this option is set to ON, the user ge</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(advanced).choice(scatterplot)</td><td>Resonances Scatter Plots</td><td>If this option is set to ON then the sca</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).choice(ldosplot)</td><td>Carrier Distribution Surface Plots</td><td>Turning this option on will display the </td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(advanced).choice(etamodel)</td><td>Reservoir Relaxation Model</td><td>The central device barriers are isolatin</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).number(eta)</td><td>Reservoir Relaxation Energy</td><td>Rate of relaxation in the contacts.  Typ</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(advanced).number(eta2)</td><td>Decay Length.</td><td>Decay length of the Reservoir relaxation</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(advanced).number(poisson)</td><td>Poisson Criterion</td><td>The maximum value in the electrostatic p</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(adaptive).choice(Eadaptive)</td><td>Adaptive energy grid</td><td>If set to off, a uniform energy grid wil</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(adaptive).number(Edif)</td><td>Homogeneous E grid spacing</td><td>Energy spacing for the homogeneous energ</td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(adaptive).number(Ethreshold)</td><td>Threshold for adding E points</td><td>When the potential change from one itera</td></tr><tr bgcolor="#ffffff"><td>input.phase(phs2).group(tabs).group(adaptive).number(Eaddcriterion)</td><td>Criterion for adding E points</td><td>Criterion for determining when E points </td></tr><tr bgcolor="#dddddd"><td>input.phase(phs2).group(tabs).group(adaptive).number(band_margin)</td><td>| Emax-Ef | for each bias</td><td>Quantities such as transmission, current</td></t ...
# <h3>LOADERS</h3>
# <table><tr bgcolor="#cccccc"><th>input.phase(phs2).loader</th><th>Label</th>
# <tr bgcolor="#dddddd"><td>/apps/rtdnegf/current/rappture/examples/3bar.xml</td><td>3-barrier device</td></tr><tr bgcolor="#ffffff"><td>/apps/rtdnegf/current/rappture/examples/6bar.xml</td><td>6-barrier device</td></tr><tr bgcolor="#dddddd"><td>/apps/rtdnegf/current/rappture/examples/1bar.xml</td><td>1-barrier device</td></tr><tr bgcolor="#ffffff"><td>/apps/rtdnegf/current/rappture/examples/2bar.xml</td><td>2-barrier device</td></tr></table>

# %%
# run the tool
io.run(verbose=True)
# Out:
# cmd= PATH=/apps/rtdnegf/current/bin:$PATH /apps/bin/rappture -execute /home/nanohub/mmh/data/sessions/1139522/tool_driver_16698.xml -tool /apps/rtdnegf/current/rappture/tool.xml > /home/nanohub/mmh/data/sessions/1139522/tool_run_16698.xml
# cache tag is ""
# Cache checking: 54042 microseconds per iteration
# checking cache=0

# %%
io.outputs
# Out:
# <h3>OUTPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# <tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(1).curve(CB)</td><td>Conduction Band at:0V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(1).curve(FL_1)</td><td>Fermi Level at:0V</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(1).curve(FL_2)</td><td>Fermi Level at:0V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(1).curve(Res1_0)</td><td>Well Resonance from Resonance finder at:0V Res No. 1</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(1).curve(Res2_0)</td><td>Well Resonance from Resonance finder at:0V Res No. 2</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(1).curve(Res2_2)</td><td>Well Resonance from Resonance finder at:0V Res No. 2</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(1).curve(TE)</td><td>Transmission Coefficient at:0V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(1).curve(J)</td><td>Current Density at:0V</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(1).curve(Jcum)</td><td>Normalized Cumulative Current Density at:0V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(1).curve(IV)</td><td>Current Voltage Characteristic</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(1).curve(IVpoint)</td><td>IV point</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(1).curve(separator)</td><td>Separator #1</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(2).curve(CB)</td><td>Conduction Band at:0.025V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(2).curve(FL_1)</td><td>Fermi Level at:0.025V</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(2).curve(FL_2)</td><td>Fermi Level at:0.025V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(2).curve(Res1_0)</td><td>Well Resonance from Resonance finder at:0.025V Res No. 1</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(2).curve(Res2_0)</td><td>Well Resonance from Resonance finder at:0.025V Res No. 2</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(2).curve(Res2_2)</td><td>Well Resonance from Resonance finder at:0.025V Res No. 2</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(2).curve(TE)</td><td>Transmission Coefficient at:0.025V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(2).curve(J)</td><td>Current Density at:0.025V</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(2).curve(Jcum)</td><td>Normalized Cumulative Current Density at:0.025V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(2).curve(IV)</td><td>Current Voltage Characteristic</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(2).curve(IVpoint)</td><td>IV point</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(2).curve(separator)</td><td>Separator #1</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(3).curve(CB)</td><td>Conduction Band at:0.05V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(3).curve(FL_1)</td><td>Fermi Level at:0.05V</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(3).curve(FL_2)</td><td>Fermi Level at:0.05V</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(3).curve(Res1_0)</td><td>Well Resonance from Resonance finder at:0.05V Res No. 1</td><td></td></tr><tr bgcolor="#ffffff"><td>output.sequence(BandsTIV).element(3).curve(Res2_0)</td><td>Well Resonance from Resonance finder at:0.05V Res No. 2</td><td></td></tr><tr bgcolor="#dddddd"><td>output.sequence(BandsTIV).element(3).curve(Res2_2)</td><td>Well Resonance from Reson ...

# %% [markdown]
# ## hublib does not have support for visualizing sequences of curves yet.  But we can look at individual curves.

# %%
io['output.sequence(BandsTIV).element(1).curve(CB)'].plot(single=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.sequence(Tplot).element(1).curve(TE)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['input.phase(phs2).loader'] = "/apps/rtdnegf/current/rappture/examples/3bar.xml" 
io.run()

# %%
io['output.sequence(BandsTIV).element(1).curve(CB)'].plot(single=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.sequence(Tplot).element(1).curve(TE)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
