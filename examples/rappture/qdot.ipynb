# %%
# %matplotlib notebook
import numpy as np
import hublib.rappture as rappture

# %%
io = rappture.Tool("qdot")
io
# Out:
# <h3>INPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# ...

# %%
# run the tool
io.run(verbose=True)
# Out:
# cmd= /apps/bin/rappture -execute /home/nanohub/mmh/data/sessions/1139522/tool_driver_17329.xml -tool /apps/qdot/current/rappture/tool.xml > /home/nanohub/mmh/data/sessions/1139522/tool_run_17329.xml
# cache tag is ""
# Cache checking: 282041 microseconds per iteration
# checking cache=1

# %%
io.outputs
# Out:
# <h3>OUTPUTS</h3>
# <table><tr bgcolor="#cccccc"><th>Path</th><th>Label</th><th>Description</th></tr>
# ...

# %% [markdown]
# ##  Hublib cannot read fields yet.  All we can look at right now is the curves.

# %%
io['output.curve(abs_sweep_0)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.curve(ldd_px)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
