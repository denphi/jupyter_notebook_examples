# %%
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=UserWarning)
import nglview as nv

# %% [markdown]
# # Show pytraj

# %%
import pytraj as pt

p_traj = pt.load(nv.datafiles.TRR, top=nv.datafiles.PDB)
p_view = nv.show_pytraj(p_traj)
p_view

# %% [markdown]
# # Show mdtraj

# %%
import mdtraj as md

m_traj = md.load(nv.datafiles.TRR, top=nv.datafiles.PDB)
m_view = nv.show_mdtraj(m_traj)
m_view

# %% [markdown]
# # Show MDAnalysis

# %%
from MDAnalysis import Universe

mda_traj = Universe(nv.datafiles.PDB, nv.datafiles.TRR)
mda_view = nv.show_mdanalysis(mda_traj)
mda_view
# Out:
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipywidgets/widgets/widget.py:166: DeprecationWarning: Widget._keys_default is deprecated: use @default decorator instead.
#   def _keys_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipywidgets/widgets/domwidget.py:22: DeprecationWarning: DOMWidget._layout_default is deprecated: use @default decorator instead.
#   def _layout_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipykernel/comm/comm.py:52: DeprecationWarning: Comm._comm_id_default is deprecated: use @default decorator instead.
#   def _comm_id_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipykernel/comm/comm.py:29: DeprecationWarning: Comm._iopub_socket_default is deprecated: use @default decorator instead.
#   def _iopub_socket_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipykernel/comm/comm.py:24: DeprecationWarning: Comm._kernel_default is deprecated: use @default decorator instead.
#   def _kernel_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipykernel/comm/comm.py:32: DeprecationWarning: Comm._session_default is deprecated: use @default decorator instead.
#   def _session_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/ipykernel/comm/comm.py:41: DeprecationWarning: Comm._topic_default is deprecated: use @default decorator instead.
#   def _topic_default(self):

# %% [markdown]
# # Add more trajectories

# %%
p_traj = pt.datafiles.load_tz2()

view = nv.show_pytraj(p_traj)
view

# %%
# add mdtraj trajectory
m_traj = md.load(nv.datafiles.PDB)

view.add_trajectory(m_traj)

# %%
# access m_traj by view[1] or by view.component_1

view.component_1.add_cartoon()

# %%
view.component_1.add_surface(opacity=0.3)

# %%
# do similiar thing for MDAnalysis and other backend

# %%
view.orientation = [[48.326230767865376, -9.748747266627937, -70.91162108709592],
 [-0.37675314228157986, 0.8477619388303186, -0.37330518996072426],
 [-24.275074005126953, -25.68029546737671, -38.50686955451965],
 [0, 0, 0]]
view.render_image()

# %%
view._display_image()
# Out:
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /opt/anaconda2-4.1.1/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):

# %%
view
